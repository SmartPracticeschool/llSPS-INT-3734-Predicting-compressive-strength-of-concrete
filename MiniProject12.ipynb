# %% [markdown]
# # Team-27(Project)

# %% [markdown]
# # Task_62740 (Importing Libraries)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Task_62741 (Importing Dataset)

# %%
path=pd.read_excel(r'C:\Users\USER\Downloads\Concrete_Data.xls')
path
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)              1030 non-null   float64
#  1   Blast Furnace Slag (component 2)(kg in a m^3 mixture)  1030 non-null   float64
#  2   Fly Ash (component 3)(kg in a m^3 mixture)             1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)              1030 non-null   float64
#  4   Superplasticizer (component 5)(kg in a m^3 mixture)    1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)   1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)      1030 non-null   float64
#  7   Age (day)                                              1030 non-null   int64
# ...

# %% [markdown]
# # Dataset Description

# %%
path.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %% [markdown]
# # Task_62742(Data Visuliazation)

# %% [markdown]
# # Checking Distrubution of Data

# %%
abc = list(path.columns.values) 
def plot(path):
    
    for col in abc:
        sns.distplot(path[col])
        print(col)
        plt.show()
    
    
plot(path)
# Out:
# Cement (component 1)(kg in a m^3 mixture)
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)
# Fly Ash (component 3)(kg in a m^3 mixture)
# Water  (component 4)(kg in a m^3 mixture)
# Superplasticizer (component 5)(kg in a m^3 mixture)
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)
# Fine Aggregate (component 7)(kg in a m^3 mixture)
# Age (day)
# Concrete compressive strength(MPa, megapascals)

# %%
for col in abc:
    
    sns.boxplot(path[col])
    print(col)
    plt.show()
# Out:
# Cement (component 1)(kg in a m^3 mixture)
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)
# Fly Ash (component 3)(kg in a m^3 mixture)
# Water  (component 4)(kg in a m^3 mixture)
# Superplasticizer (component 5)(kg in a m^3 mixture)
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)
# Fine Aggregate (component 7)(kg in a m^3 mixture)
# Age (day)
# Concrete compressive strength(MPa, megapascals)

# %% [markdown]
# # Data Visualization in Area

# %%
path.plot.area(alpha=1)

# %% [markdown]
# # Data Visualization in Barplots

# %%
path.plot.bar()

# %% [markdown]
# # Data Visualization in Histograms

# %%
path.plot.hist(bins=50)

# %%
path.boxplot(figsize=(15,15))

# %% [markdown]
# # Task_62743(Taking Care Of Missing Data)

# %%
path.isnull().any().any()
# Out:
# False

# %%
path.isnull().any()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                False
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    False
# Fly Ash (component 3)(kg in a m^3 mixture)               False
# Water  (component 4)(kg in a m^3 mixture)                False
# Superplasticizer (component 5)(kg in a m^3 mixture)      False
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     False
# Fine Aggregate (component 7)(kg in a m^3 mixture)        False
# Age (day)                                                False
# Concrete compressive strength(MPa, megapascals)          False
# dtype: bool

# %% [markdown]
# # Task_62744(Label Encoding)
# Label encoding not requried in our project

# %% [markdown]
# # Task_62745(One Hot Encoding)
# one hot encoding not requried in our project

# %%
x=path.iloc[:,0:8].values   #independent variables

y=path.iloc[:,-1].values    #dependent variables

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler(with_mean=False)
x=sc.fit_transform(x)
x
# Out:
# array([[ 5.16962112,  0.        ,  0.        , ..., 13.38204667,
#          8.43560697,  0.44346432],
#        [ 5.16962112,  0.        ,  0.        , ..., 13.57505696,
#          8.43560697,  0.44346432],
#        [ 3.18314634,  1.65241894,  0.        , ..., 11.99237259,
#          7.41235287,  4.27626312],
#        ...,
#        [ 1.42164581,  1.61647158,  1.69779299, ..., 11.48282543,
#          9.73339266,  0.44346432],
#        [ 1.52312356,  2.16495871,  0.        , ..., 12.7335321 ,
#          9.84445317,  0.44346432],
#        [ 2.49769287,  1.1653902 ,  1.22409936, ..., 11.12382629,
#          9.50253655,  0.44346432]])

# %%
import joblib
joblib.dump(sc,'Transformss')
# Out:
# ['Transformss']

# %% [markdown]
# # Task_62746( Feature Scaling)

# %%
x=path.iloc[:,0:8].values   #independent variables

y=path.iloc[:,-1].values    #dependent variables
x
# Out:
# array([[ 540. ,    0. ,    0. , ..., 1040. ,  676. ,   28. ],
#        [ 540. ,    0. ,    0. , ..., 1055. ,  676. ,   28. ],
#        [ 332.5,  142.5,    0. , ...,  932. ,  594. ,  270. ],
#        ...,
#        [ 148.5,  139.4,  108.6, ...,  892.4,  780. ,   28. ],
#        [ 159.1,  186.7,    0. , ...,  989.6,  788.9,   28. ],
#        [ 260.9,  100.5,   78.3, ...,  864.5,  761.5,   28. ]])

# %%
y
# Out:
# array([79.98611076, 61.88736576, 40.26953526, ..., 23.69660064,
#        32.76803638, 32.40123514])

# %%
x.shape
# Out:
# (1030, 8)

# %%
y.shape
# Out:
# (1030,)

# %%
plt.scatter(x[:,0],y)

# %%
plt.scatter(x[:,1],y)

# %%
plt.scatter(x[:,2],y)

# %%
plt.scatter(x[:,3],y)

# %%
plt.scatter(x[:,4],y)

# %%
plt.scatter(x[:,5],y)

# %%
plt.scatter(x[:,6],y)

# %%
plt.scatter(x[:,7],y)

# %% [markdown]
# # Task_62747(Train& Split the data)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_test
# Out:
# array([[ 500.  ,    0.  ,    0.  , ..., 1125.  ,  613.  ,    3.  ],
#        [ 122.6 ,  183.9 ,    0.  , ...,  958.2 ,  800.1 ,    7.  ],
#        [ 362.6 ,  189.  ,    0.  , ...,  944.7 ,  755.8 ,   91.  ],
#        ...,
#        [ 173.54,   50.05,  173.53, ..., 1006.2 ,  793.5 ,   14.  ],
#        [ 262.  ,  111.  ,   86.  , ...,  895.  ,  733.  ,   28.  ],
#        [ 250.  ,    0.  ,   95.69, ...,  956.86,  861.17,    3.  ]])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
mr= RandomForestRegressor(n_estimators=100,criterion="mse",random_state=0)
mr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
mr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
joblib.dump(mr,'Multyy.save')
# Out:
# ['Multyy.save']

# %%
y_pred = mr.predict(x_test)
y_pred
# Out:
# array([21.70044352,  7.84885098, 79.15667113, 63.0564846 , 11.51929025,
#        48.91597136, 60.44543013, 23.28519031, 72.25964276, 51.67228929,
#        18.79103406, 43.36188436, 35.59719772, 15.4170084 , 53.64496681,
#        56.52162714, 38.79127901, 34.87065549, 50.98841184, 37.98930023,
#        61.59441693, 28.76072602, 27.57090418, 39.46729841, 15.64185342,
#        25.45076548, 62.75741552, 25.17281013, 60.5490436 , 62.24669307,
#        20.82350589, 44.9181755 , 27.34718301, 37.86161617, 20.80561399,
#         9.20208749, 33.20375566, 26.29530464, 34.40440424, 33.04823942,
#        35.25820897, 35.3313013 , 32.16126302, 38.48489558, 62.44943349,
#        33.62133187, 26.98523569, 32.05466314, 34.5921525 , 50.86962202,
#        43.13353582, 26.37501496, 22.64642527, 38.47414665, 52.92279881,
#        45.44163947, 44.29156592, 56.02076961, 64.13092066, 38.07893112,
#        36.02341799, 22.66431718, 59.0472969 , 45.61072011, 12.54101686,
# ...

# %%
y_test
# Out:
# array([26.0621928 , 10.35455057, 79.29663476, 74.98740976,  9.69472204,
#        47.09810556, 58.99846132, 22.7182342 , 61.88736576, 52.1243856 ,
#        17.54026944, 48.15300384, 38.32797084, 17.20035777, 56.83350668,
#        55.25460664, 33.35684888, 34.6806428 , 52.61391356, 39.94134468,
#        61.45989064, 27.62730332, 32.90179472, 41.63745564, 17.54026944,
#        26.84819544, 66.89985628, 21.0634918 , 61.06688932, 66.9481196 ,
#        20.87043852, 48.79421652, 24.04616498, 47.81378165, 21.16001844,
#         6.94095489, 28.59946448, 26.31040416, 33.94772981, 25.72434956,
#        37.79707432, 35.17017076, 32.23989776, 37.81086384, 57.226508  ,
#        33.39821744, 30.14389072, 33.79811352, 35.07640202, 52.90831981,
#        40.93419012, 21.7529678 , 16.49916068, 42.34761592, 50.93848688,
#        64.0178466 , 52.20022796, 53.38612668, 64.30053176, 44.52045028,
#        37.42475728, 22.13907436, 62.93536928, 45.69846928, 14.63826496,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9256348724983465

# %%
mr.predict([[540,0,0,162,2.5,1040,676,28]])
# Out:
# array([74.47706652])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 19.586606598901625

# %%
from math import sqrt
rmse=sqrt(mse)
rmse
# Out:
# 4.4256758352709955

# %%
x.shape
# Out:
# (1030, 8)
